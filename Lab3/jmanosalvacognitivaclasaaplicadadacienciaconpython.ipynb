# %% [markdown]
# ![1-Data Visualization with Python_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2-Data Analysis with Python_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![3- Certificado Cognitiveclass PY0101EN _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Captura linkedin.png](data:image/png;base64,...)
